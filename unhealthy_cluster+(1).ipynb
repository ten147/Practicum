# %%
import pandas as pd
import seaborn as sns  
from scipy.cluster import hierarchy  
from scipy import cluster   
import matplotlib.pyplot as plt
from sklearn import decomposition as skldec

# %%
df=pd.read_csv('df_unhealth.csv')

# %%
df.dtypes
# Out:
# State        object
# BINGE       float64
# CSMOKING    float64
# LPA         float64
# OBESITY     float64
# SLEEP       float64
# dtype: object

# %%
df.set_index(["State"], inplace=True)

# %% [markdown]
# ### Hierarchical Clustering

# %%
Z = hierarchy.linkage(df, method ='ward',metric='euclidean')
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('state',fontsize=18)
plt.ylabel('distance')
hierarchy.dendrogram(
    Z,
    labels = df.index,
    leaf_rotation=90.,  
    leaf_font_size=20.,
)
plt.show()

# %% [markdown]
# #### Based on the Hierarchical Clustering Dendrogram, we can spilt the data into 3 clusters.

# %% [markdown]
# ## heat map

# %%
sns.clustermap(df,method ='ward',metric='euclidean')
